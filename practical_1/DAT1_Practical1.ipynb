# %%
print("xd")
# Out:
# xd

# %% [markdown]
# ### no iea tf is going on

# %%
import numpy as np
x = np.sqrt(36)
print("the root of 36 is:",x)
# Out:
# the root of 36 is: 6.0

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fc17d851ef81> in <module>
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %%
print(abs)
